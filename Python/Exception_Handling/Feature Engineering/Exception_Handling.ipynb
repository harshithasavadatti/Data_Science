# %%
import pandas as pd
import json
import os
from glob import glob

def json_files_to_dataframe(directory_path):
    """
    Convert each JSON file into one row in DataFrame
    """
    # Get all JSON files in directory
    json_files = glob(os.path.join(directory_path, '*.json'))
    
    rows = []
    
    for file_path in json_files:
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
            # Add filename for reference
            if isinstance(data, dict):
                data['filename'] = os.path.basename(file_path)
            
            rows.append(data)
            
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            # Add empty row with filename to maintain order
            rows.append({'filename': os.path.basename(file_path), 'error': str(e)})
    
    # Create DataFrame where each file is one row
    df = pd.DataFrame(rows)
    return df

# Usage
df = json_files_to_dataframe('H:\Python\Exception_Handling\Feature Engineering\json files')
print(f"Created DataFrame with {len(df)} rows (files)")
df.head()
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\P'
# <>:36: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\harsh\AppData\Local\Temp\ipykernel_23984\559034584.py:36: SyntaxWarning: invalid escape sequence '\P'
#   df = json_files_to_dataframe('H:\Python\Exception_Handling\Feature Engineering\json files')
# Created DataFrame with 19 rows (files)
#   ticket_id  priority  category    status          created_date  \
# 0   TKT-002  CRITICAL  Security  Resolved  2024-01-16T11:20:00Z
# 1   TKT-003      HIGH   Network  Resolved  2024-01-17T08:15:00Z
# 2   TKT-004    MEDIUM     Email  Resolved  2024-01-18T14:30:00Z
# 3   TKT-005    MEDIUM  Software  Resolved  2024-01-19T10:45:00Z
# 4   TKT-006      HIGH    Backup  Resolved  2024-01-20T16:00:00Z
#
#           resolved_date   assigned_to  \
# 0  2024-01-17T16:30:00Z   Sarah Davis
# 1  2024-01-17T12:30:00Z     Mike Chen
# 2  2024-01-18T17:45:00Z    Lisa Brown
# 3  2024-01-19T13:20:00Z    Tom Wilson
# 4  2024-01-21T09:30:00Z  Alex Johnson
#
#                                                 user  \
# 0  {'name': 'Bob Wilson', 'department': 'Marketin...
# 1  {'name': 'Carlos Rodriguez', 'department': 'HR...
# 2  {'name': 'David Kim', 'department': 'IT', 'ema...
# 3  {'name': 'Emma Thompson', 'department': 'Sales...
# 4  {'name': 'Jennifer Lee', 'department': 'Operat...
#
#                              subject  \
# 0          Suspected Security Breach
# 1        Network Outage - Building A
# 2   Email Server Overwhelmed by Spam
# 3  Software License Compliance Issue
# 4             Backup Data Corruption
#
#                                          description  \
# 0  Security monitoring detected unauthorized acce...
# 1  Complete network outage affecting entire Build...
# 2  Email server is receiving massive amounts of s...
# 3  Software audit revealed that company is using ...
# 4  Critical backup files are corrupted and cannot...
#
#                                           resolution  \
# 0  Blocked malicious IPs and implemented addition...
# 1  Replaced failed network switch and restored co...
# 2  Updated spam filters and blocked malicious sen...
# 3  Purchased additional licenses and implemented ...
# 4  Restored from secondary backup location and im...
#
#                                     resolution_steps  time_spent_minutes  \
# 0  [Analyzed security logs and identified attack ...                1270
# 1  [Identified failed core network switch in Buil...                 255
# 2  [Analyzed spam patterns and identified source ...                 195
# 3  [Conducted comprehensive software audit across...                 155
# 4  [Identified corrupted backup files and extent ...                1050
#
#                                                 tags  \
# 0  [security, breach, firewall, authentication, m...
# 1  [network, outage, switch, connectivity, infras...
# 2    [email, spam, performance, filtering, security]
# 3      [license, compliance, audit, software, legal]
# 4  [backup, corruption, disaster_recovery, data_i...
#
#                                          impact  \
# 0            Critical - Potential data exposure
# 1                High - Entire building offline
# 2  Medium - Email delays and performance issues
# 3                Medium - Legal compliance risk
# 4                     High - Data recovery risk
#
#                                           root_cause  \
# 0  Weak password policies and insufficient monito...
# 1            Hardware failure in core network switch
# 2     Insufficient spam filtering and outdated rules
# 3       Insufficient license tracking and management
# 4    Insufficient backup verification and monitoring
#
#                                  prevention_measures  \
# 0  Enhanced security policies and real-time monit...
# 1        Implement redundant switches and monitoring
# 2         Regular spam filter updates and monitoring
# 3  Implement license management system and regula...
# 4  Implement automated backup verification and mu...
#
#                             filename
# 0    ticket_002_security_breach.json
# 1     ticket_003_network_outage.json
# 2         ticket_004_email_spam.json
# 3   ticket_005_software_license.json
# 4  ticket_006_backup_corruption.json

# %%
df.to_csv('output.csv', index=False)
print("CSV file saved as 'output.csv'")
# Out:
# CSV file saved as 'output.csv'

# %%
# Check if file exists
if os.path.exists('output.csv'):
    print("CSV file created successfully")
    
    # Read it back to verify
    df_check = pd.read_csv('output.csv')
    print(f"Verified CSV has {len(df_check)} rows")
else:
    print("CSV file was not created")
# Out:
# CSV file created successfully
# Verified CSV has 19 rows

# %%
# First, implement the process_file function
def process_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        result = {
            'filename': os.path.basename(file_path),
            'file_path': file_path,
            'file_size': os.path.getsize(file_path),
            'data': data
        }
        return result
        
    except Exception as e:
        return {
            'filename': os.path.basename(file_path),
            'error': str(e),
            'data': None
        }

# Then modify main function
def json_files_to_dataframe_improved(directory_path):
    json_files = glob(os.path.join(directory_path, '*.json'))
    rows = [process_file(f) for f in json_files]
    return pd.DataFrame(rows)

df = json_files_to_dataframe_improved('H:\Python\Exception_Handling\Feature Engineering\json files')

# Analysis requires unpacking:
names = [row['data']['name'] for row in df['data'] if row and 'name' in row]
large_files = df[df['file_size'] > 1000]['filename']  # Rich metadata!

df.head()
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\P'
# <>:28: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\harsh\AppData\Local\Temp\ipykernel_23984\1550121571.py:28: SyntaxWarning: invalid escape sequence '\P'
#   df = json_files_to_dataframe_improved('H:\Python\Exception_Handling\Feature Engineering\json files')
#                             filename  \
# 0    ticket_002_security_breach.json
# 1     ticket_003_network_outage.json
# 2         ticket_004_email_spam.json
# 3   ticket_005_software_license.json
# 4  ticket_006_backup_corruption.json
#
#                                            file_path  file_size  \
# 0  H:\Python\Exception_Handling\Feature Engineeri...       1357
# 1  H:\Python\Exception_Handling\Feature Engineeri...       1307
# 2  H:\Python\Exception_Handling\Feature Engineeri...       1322
# 3  H:\Python\Exception_Handling\Feature Engineeri...       1362
# 4  H:\Python\Exception_Handling\Feature Engineeri...       1380
#
#                                                 data
# 0  {'ticket_id': 'TKT-002', 'priority': 'CRITICAL...
# 1  {'ticket_id': 'TKT-003', 'priority': 'HIGH', '...
# 2  {'ticket_id': 'TKT-004', 'priority': 'MEDIUM',...
# 3  {'ticket_id': 'TKT-005', 'priority': 'MEDIUM',...
# 4  {'ticket_id': 'TKT-006', 'priority': 'HIGH', '...

# %%
df.to_csv('output_improved.csv', index=False)
